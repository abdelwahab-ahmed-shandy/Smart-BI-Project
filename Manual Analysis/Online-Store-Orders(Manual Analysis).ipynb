# %%
# أستدعاء المكاتب
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import calendar
from sklearn.preprocessing import MinMaxScaler, StandardScaler, LabelEncoder
scaler_minmax = MinMaxScaler()
scaler_standard  = StandardScaler()
le=LabelEncoder()

# %%
# قراءة الملف
df=pd.read_excel("Online-Store-Orders.xlsx")

# %%
# عدد العمليات
num_transactions = len(df)
print("عدد العمليات=", num_transactions)
# Out:
# عدد العمليات= 1200

# %%
# أجمالي المبيعات
total_sales = df["TotalPrice"].sum()
print("إجمالي المبيعات=", total_sales)
# Out:
# إجمالي المبيعات= 1264761.96

# %%
# المنتج الأكثر طلباً
top_product = df.groupby("Product")["Quantity"].sum().idxmax()
print("المنتج الأكثر طلبًا=", top_product)
# Out:
# المنتج الأكثر طلبًا= Chair

# %%
# أكثر خمس منتجات طلباً
top_5 =df.groupby("Product")["Quantity"].sum().sort_values(ascending=False).head(5)
print("أكثر خمس منتجات طلباً =",top_5)
# Out:
# أكثر خمس منتجات طلباً = Product
# Chair      562
# Printer    542
# Laptop     535
# Desk       508
# Tablet     497
# Name: Quantity, dtype: int64

# %%
#مخطط عام 2025
year_selected = 2025
df_year = df[df['Date'].dt.year == year_selected]
# تجميع شهري
monthly_sales = df_year.groupby(df_year['Date'].dt.month)['TotalPrice'].sum().sort_index()
# أسماء الشهور
month_names = [calendar.month_name[i] for i in monthly_sales.index]
# الرسم
plt.figure()
plt.plot(month_names, monthly_sales.values)
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.show()

# %%
#مخطط عام 2024
year_selected = 2024
df_year = df[df['Date'].dt.year == year_selected]
# تجميع شهري
monthly_sales = df_year.groupby(df_year['Date'].dt.month)['TotalPrice'].sum().sort_index()
# أسماء الشهور
month_names = [calendar.month_name[i] for i in monthly_sales.index]
# الرسم
plt.figure()
plt.plot(month_names, monthly_sales.values)
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.show()

# %%
#مخطط عام 2023
year_selected = 2023
df_year = df[df['Date'].dt.year == year_selected]
# تجميع شهري
monthly_sales = df_year.groupby(df_year['Date'].dt.month)['TotalPrice'].sum().sort_index()
# أسماء الشهور
month_names = [calendar.month_name[i] for i in monthly_sales.index]
# الرسم
plt.figure()
plt.plot(month_names, monthly_sales.values)
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.show()

# %%
#مخطط جميع الأعوام
df['Date'] = pd.to_datetime(df['Date'])
df['Month'] = df['Date'].dt.month_name()
monthly_sales = df.groupby('Month')['TotalPrice'].sum()
monthly_sales = monthly_sales.reindex(month_names)
plt.figure()
plt.plot(monthly_sales.index, monthly_sales.values)
plt.xticks(rotation=45)
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.show()
